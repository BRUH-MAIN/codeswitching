# %% [markdown]
# # Track 2 · Stage 2 — Synthesize the code-mixed **audio**
#
# Pulls the ~16k sentences that `01a` pushed, voices them with **Indic Parler-TTS**
# (Rohit ♂ / Divya ♀, 50/50), and pushes ~22h of 16 kHz audio to
# `RohanRamesh/hi-en-synth-cs`.
#
# **Separate notebook because `parler-tts` hard-pins `transformers==4.46.1`**, which cannot
# load the Gemma 3 used in `01a`. No LLM is loaded here.
#
# ### Before you run
# * **Accept the licence for [`ai4bharat/indic-parler-tts`](https://huggingface.co/ai4bharat/indic-parler-tts)** — it is gated and has no
#   ungated mirror. If your HF token is *fine-grained*, also tick **"Read access to contents
#   of all public gated repos you can access"**; accepting the licence alone is not enough.
# * HF **write** token in Kaggle Secrets as `HF_TOKEN`. Internet **on**, **GPU T4 ×2**.
#
# Runtime ≈ 4–6h. Sharded — re-running skips every clip already on disk, so a 12h timeout
# costs at most the in-flight shard.

# %% [markdown]
# ## 0 · Install
#
# **Cell order matters.** The `transformers` downgrade silently no-ops if anything has already imported `transformers`. Do not import it above this cell.

# %%
# !pip install -q "transformers==4.46.1" "datasets<4" accelerate soxr librosa soundfile
# !pip install -q git+https://github.com/huggingface/parler-tts.git
# !pip install -q --force-reinstall --no-deps git+https://github.com/BRUH-MAIN/codeswitching.git

# This NOTEBOOK's own version. `pip install` updates the csasr PACKAGE but NOT the
# .ipynb -- an old notebook against a new package is a real and confusing failure.
NOTEBOOK_VERSION = "0.10.2"

import csasr, transformers
assert csasr.__version__ == NOTEBOOK_VERSION, (
    f"csasr package is {csasr.__version__} but this NOTEBOOK is {NOTEBOOK_VERSION}.\n"
    "  package older  -> restart the kernel (Run > Restart & clear); pip skips a\n"
    "                    reinstall when the version looks satisfied.\n"
    "  notebook older -> re-download it from the repo; pip does NOT update .ipynb files."
)
assert transformers.__version__ == "4.46.1", (
    f"transformers is {transformers.__version__}, expected 4.46.1 - something imported "
    "it before the downgrade took effect. Restart the kernel."
)
print("csasr", csasr.__version__, "| transformers", transformers.__version__)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 54.3 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 25.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 33.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 69.5 MB/s eta 0:00:00:00:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tpot 1.1.0 requires dill>=0.3.9, but you have dill 0.3.8 which is incompatible.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.2/295.2 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 8.9 MB/s eta 0:00:00
#   Building wheel for parler_tts (pyproject.toml) ... done
#   Building wheel for descript-audiotools (setup.py) ... done
#   Building wheel for argbind (setup.py) ... done
#   Building wheel for randomname (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.39.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-adk 1.29.0 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# grpcio-tools 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.9 which is incompatible.
# a2a-sdk 0.3.26 requires protobuf>=5.29.5, but you have protobuf 4.25.9 which is incompatible.
# tensorflow 2.20.0 requires protobuf>=5.28.0, but you have protobuf 4.25.9 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.9 which is incompatible.
# opentelemetry-proto 1.38.0 requires protobuf<7.0,>=5.0, but you have protobuf 4.25.9 which is incompatible.
# grain 0.2.16 requires protobuf>=5.28.3, but you have protobuf 4.25.9 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.9 which is incompatible.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for csasr (pyproject.toml) ... done
# csasr 0.10.2 | transformers 4.46.1

# %%
import os, subprocess, sys, itertools
from pathlib import Path

os.environ["HF_HOME"] = "/kaggle/temp/hf"
Path(os.environ["HF_HOME"]).mkdir(parents=True, exist_ok=True)

# NEVER let transformers import TensorFlow. `parler_tts` imports
# `transformers.PreTrainedModel`, which reaches image_transforms.py and runs
# `if is_tf_available(): import tensorflow`. Kaggle HAS TensorFlow, but it wants a
# newer protobuf than our pins leave behind, so it dies with
#   ImportError: cannot import name 'runtime_version' from 'google.protobuf'
# We never use TF. USE_TF=0 makes is_tf_available() False and the import vanishes.
os.environ["USE_TF"] = "0"
os.environ["USE_TORCH"] = "1"

from kaggle_secrets import UserSecretsClient
os.environ["HF_TOKEN"] = UserSecretsClient().get_secret("HF_TOKEN")
from huggingface_hub import login
login(token=os.environ["HF_TOKEN"])
HF_TOKEN = os.environ["HF_TOKEN"]

import torch
N_GPU = max(1, torch.cuda.device_count())

SYNTH_REPO = "RohanRamesh/hi-en-synth-cs"
TTS        = "ai4bharat/indic-parler-tts"
NUM_SHARDS = 4          # finer than N_GPU on purpose: a timeout costs one shard

WORK  = Path("/kaggle/working")
MAN   = WORK / "manifests"; MAN.mkdir(parents=True, exist_ok=True)
AUDIO = WORK / "audio";     AUDIO.mkdir(parents=True, exist_ok=True)

def run(*args):
    print(">", " ".join(str(a) for a in args), flush=True)
    p = subprocess.run([sys.executable, "-m", *args])
    if p.returncode != 0:
        raise RuntimeError(
            f"{args[0]} failed (exit {p.returncode}). The real error is printed ABOVE "
            f"this traceback - scroll up in this cell's output."
        )

def run_parallel(cmds):
    """One process per GPU, pinned with CUDA_VISIBLE_DEVICES; wait for all.

    Running the shards SEQUENTIALLY leaves Kaggle's second T4 completely idle --
    the same waste already fixed in 01a and 03_eval.
    """
    procs = []
    for i, cmd in enumerate(cmds):
        gpu = i % N_GPU
        env = dict(os.environ, CUDA_VISIBLE_DEVICES=str(gpu))
        print(f"> GPU{gpu}: {' '.join(str(c) for c in cmd)}", flush=True)
        procs.append(subprocess.Popen(
            [sys.executable, "-m", *[str(c) for c in cmd]], env=env))
    for i, p in enumerate(procs):
        if p.wait() != 0:
            raise RuntimeError(f"shard {i} failed (exit {p.returncode}). The real error "
                               "is printed ABOVE - scroll up in this cell's output.")

print(f"{N_GPU} GPU(s), {NUM_SHARDS} shards")
# !nvidia-smi --query-gpu=name,memory.total --format=csv
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# 2 GPU(s), 4 shards
# name, memory.total [MiB]
# Tesla T4, 15360 MiB
# Tesla T4, 15360 MiB

# %% [markdown]
# ## 0b · PREFLIGHT — Parler-TTS is gated
#
# Fails in seconds rather than after a 6-hour run has started.

# %%
from huggingface_hub import model_info
from huggingface_hub.utils import GatedRepoError, RepositoryNotFoundError

try:
    model_info(TTS, token=HF_TOKEN)
    print(f"  OK  {TTS}")
except GatedRepoError:
    raise SystemExit(
        f"PREFLIGHT FAILED: {TTS} is gated.\n"
        f"  1. Accept the licence at https://huggingface.co/{TTS}\n"
        f"  2. If your HF token is FINE-GRAINED, also tick 'Read access to contents of\n"
        f"     all public gated repos you can access', then update the Kaggle Secret."
    )
except RepositoryNotFoundError:
    raise SystemExit(f"PREFLIGHT FAILED: {TTS} not found, or your token cannot see it.")
# Out:
#   OK  ai4bharat/indic-parler-tts

# %% [markdown]
# ## 1 · Pull the sentences generated by `01a`

# %%
from datasets import load_dataset
from csasr.manifest import read_jsonl, write_jsonl

ds = load_dataset(SYNTH_REPO, "sentences", split="train", token=HF_TOKEN)
write_jsonl(MAN / "sentences.jsonl", [dict(r) for r in ds])
print(f"{len(ds):,} sentences to synthesize")
print(ds[0]["text"])
# Out:
# README.md: 0.00B [00:00, ?B/s]
# sentences/train-00000-of-00001.parquet:   0%|          | 0.00/1.28M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/18054 [00:00<?, ? examples/s]
# 18,054 sentences to synthesize
# If you want to use this app, you will need to account बनाना होगा.

# %% [markdown]
# ## 2 · Synthesize
#
# Indic Parler-TTS emits **44.1 kHz** → resampled to 16 kHz and written as **int16**
# (`synthesize.py` reads `model.config.sampling_rate`; it never hardcodes the rate).
#
# **Both GPUs, in parallel.** Shards run two at a time, one per T4 — running them
# sequentially would leave half the machine idle, which is exactly the waste already fixed in
# 01a and 03_eval.
#
# **Resumable.** Every clip already on disk is skipped, so re-running this cell after a
# timeout costs only the in-flight batch.

# %%
BATCH = 16     # Parler is small (938M); 8 left the GPU underfed

# Two shards at a time -- one per GPU.
for start in range(0, NUM_SHARDS, N_GPU):
    group = range(start, min(start + N_GPU, NUM_SHARDS))
    run_parallel([
        ["csasr.tts.synthesize",
         "--sentences", MAN / "sentences.jsonl",
         "--audio-dir", AUDIO,
         "--out", MAN / f"train_t2.shard{s}.jsonl",
         "--shard", s, "--num-shards", NUM_SHARDS,
         "--batch-size", BATCH]
        for s in group
    ])
# Out:
# > GPU0: csasr.tts.synthesize --sentences /kaggle/working/manifests/sentences.jsonl --audio-dir /kaggle/working/audio --out /kaggle/working/manifests/train_t2.shard0.jsonl --shard 0 --num-shards 4 --batch-size 16
# > GPU1: csasr.tts.synthesize --sentences /kaggle/working/manifests/sentences.jsonl --audio-dir /kaggle/working/audio --out /kaggle/working/manifests/train_t2.shard1.jsonl --shard 1 --num-shards 4 --batch-size 16
# WARNING:parler_tts.modeling_parler_tts:Flash attention 2 is not installed
# WARNING:parler_tts.modeling_parler_tts:Flash attention 2 is not installed
# WARNING:parler_tts.modeling_parler_tts:Config of the text_encoder: <class 'transformers.models.t5.modeling_t5.T5EncoderModel'> is overwritten by shared text_encoder config: T5Config {
#   "_name_or_path": "google/flan-t5-large",
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "classifier_dropout": 0.0,
#   "d_ff": 2816,
#   "d_kv": 64,
#   "d_model": 1024,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "gelu_new",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "gated-gelu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 24,
#   "num_heads": 16,
#   "num_layers": 24,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "tie_word_embeddings": false,
#   "transformers_version": "4.46.1",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# WARNING:parler_tts.modeling_parler_tts:Config of the audio_encoder: <class 'transformers.models.dac.modeling_dac.DacModel'> is overwritten by shared audio_encoder config: DacConfig {
#   "_name_or_path": "ylacombe/dac_44khz",
#   "architectures": [
#     "DacModel"
#   ],
#   "codebook_dim": 8,
#   "codebook_loss_weight": 1.0,
#   "codebook_size": 1024,
#   "commitment_loss_weight": 0.25,
#   "decoder_hidden_size": 1536,
#   "downsampling_ratios": [
#     2,
#     4,
#     8,
#     8
#   ],
#   "encoder_hidden_size": 64,
#   "hidden_size": 1024,
#   "hop_length": 512,
#   "model_type": "dac",
#   "n_codebooks": 9,
#   "quantizer_dropout": 0.0,
#   "sampling_rate": 44100,
#   "torch_dtype": "float32",
#   "transformers_version": "4.46.1",
#   "upsampling_ratios": [
#     8,
#     8,
#     4,
#     2
#   ]
# }
#
# WARNING:parler_tts.modeling_parler_tts:Config of the decoder: <class 'parler_tts.modeling_parler_tts.ParlerTTSForCausalLM'> is overwritten by shared decoder config: ParlerTTSDecoderConfig {
#   "_name_or_path": "/fsx/yoach/tmp/artefacts/parler-tts-mini-v2-empty/decoder",
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_cross_attention": true,
#   "architectures": [
#     "ParlerTTSForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 1025,
#   "codebook_weights": null,
#   "cross_attention_implementation_strategy": null,
#   "delay_strategy": "delay",
#   "dropout": 0.1,
#   "eos_token_id": 1024,
#   "ffn_dim": 4096,
#   "hidden_size": 1024,
#   "initializer_factor": 0.02,
#   "is_decoder": true,
#   "layerdrop": 0.0,
#   "max_position_embeddings": 4096,
#   "model_type": "parler_tts_decoder",
#   "num_attention_heads": 16,
#   "num_codebooks": 9,
#   "num_cross_attention_key_value_heads": 16,
#   "num_hidden_layers": 24,
#   "num_key_value_heads": 16,
#   "pad_token_id": 1024,
#   "rope_embeddings": false,
#   "rope_theta": 10000.0,
#   "scale_embedding": false,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float32",
#   "transformers_version": "4.46.1",
#   "use_cache": true,
#   "use_fused_lm_heads": true,
#   "vocab_size": 1088
# }
#
# WARNING:parler_tts.modeling_parler_tts:Config of the text_encoder: <class 'transformers.models.t5.modeling_t5.T5EncoderModel'> is overwritten by shared text_encoder config: T5Config {
#   "_name_or_path": "google/flan-t5-large",
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "classifier_dropout": 0.0,
#   "d_ff": 2816,
#   "d_kv": 64,
#   "d_model": 1024,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "gelu_new",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "gated-gelu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 24,
#   "num_heads": 16,
#   "num_layers": 24,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "tie_word_embeddings": false,
#   "transformers_version": "4.46.1",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# WARNING:parler_tts.modeling_parler_tts:Config of the audio_encoder: <class 'transformers.models.dac.modeling_dac.DacModel'> is overwritten by shared audio_encoder config: DacConfig {
#   "_name_or_path": "ylacombe/dac_44khz",
#   "architectures": [
#     "DacModel"
#   ],
#   "codebook_dim": 8,
#   "codebook_loss_weight": 1.0,
#   "codebook_size": 1024,
#   "commitment_loss_weight": 0.25,
#   "decoder_hidden_size": 1536,
#   "downsampling_ratios": [
#     2,
#     4,
#     8,
#     8
#   ],
#   "encoder_hidden_size": 64,
#   "hidden_size": 1024,
#   "hop_length": 512,
#   "model_type": "dac",
#   "n_codebooks": 9,
#   "quantizer_dropout": 0.0,
#   "sampling_rate": 44100,
#   "torch_dtype": "float32",
#   "transformers_version": "4.46.1",
#   "upsampling_ratios": [
#     8,
#     8,
#     4,
#     2
#   ]
# }
#
# WARNING:parler_tts.modeling_parler_tts:Config of the decoder: <class 'parler_tts.modeling_parler_tts.ParlerTTSForCausalLM'> is overwritten by shared decoder config: ParlerTTSDecoderConfig {
#   "_name_or_path": "/fsx/yoach/tmp/artefacts/parler-tts-mini-v2-empty/decoder",
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_cross_attention": true,
#   "architectures": [
#     "ParlerTTSForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 1025,
#   "codebook_weights": null,
#   "cross_attention_implementation_strategy": null,
#   "delay_strategy": "delay",
#   "dropout": 0.1,
#   "eos_token_id": 1024,
#   "ffn_dim": 4096,
#   "hidden_size": 1024,
#   "initializer_factor": 0.02,
#   "is_decoder": true,
#   "layerdrop": 0.0,
#   "max_position_embeddings": 4096,
#   "model_type": "parler_tts_decoder",
#   "num_attention_heads": 16,
#   "num_codebooks": 9,
#   "num_cross_attention_key_value_heads": 16,
#   "num_hidden_layers": 24,
#   "num_key_value_heads": 16,
#   "pad_token_id": 1024,
#   "rope_embeddings": false,
#   "rope_theta": 10000.0,
#   "scale_embedding": false,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float32",
#   "transformers_version": "4.46.1",
#   "use_cache": true,
#   "use_fused_lm_heads": true,
#   "vocab_size": 1088
# }
# [tts] shard 1/4: 4,514 sentences, 0 already synthesized, 4,514 to go
# [tts] model sampling rate 44100 Hz -> resampling to 16000 Hz
# [tts] shard 0/4: 4,514 sentences, 0 already synthesized, 4,514 to go
# [tts] model sampling rate 44100 Hz -> resampling to 16000 Hz
# tts:   0%|          | 0/283 [00:00<?, ?batch/s]WARNING:parler_tts.modeling_parler_tts:`prompt_attention_mask` is specified but `attention_mask` is not. A full `attention_mask` will be created. Make sure this is the intended behaviour.
# WARNING:parler_tts.modeling_parler_tts:`prompt_attention_mask` is specified but `attention_mask` is not. A full `attention_mask` will be created. Make sure this is the intended behaviour.
# tts: 100%|██████████| 283/283 [1:07:52<00:00, 14.39s/batch]
# [tts] shard 1: wrote 4,504 clips (5.96 h), dropped 10
# tts: 100%|██████████| 283/283 [1:09:58<00:00, 14.83s/batch]
# [tts] shard 0: wrote 4,501 clips (5.95 h), dropped 13
# > GPU0: csasr.tts.synthesize --sentences /kaggle/working/manifests/sentences.jsonl --audio-dir /kaggle/working/audio --out /kaggle/working/manifests/train_t2.shard2.jsonl --shard 2 --num-shards 4 --batch-size 16
# > GPU1: csasr.tts.synthesize --sentences /kaggle/working/manifests/sentences.jsonl --audio-dir /kaggle/working/audio --out /kaggle/working/manifests/train_t2.shard3.jsonl --shard 3 --num-shards 4 --batch-size 16
# WARNING:parler_tts.modeling_parler_tts:Flash attention 2 is not installed
# WARNING:parler_tts.modeling_parler_tts:Flash attention 2 is not installed
# WARNING:parler_tts.modeling_parler_tts:Config of the text_encoder: <class 'transformers.models.t5.modeling_t5.T5EncoderModel'> is overwritten by shared text_encoder config: T5Config {
#   "_name_or_path": "google/flan-t5-large",
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "classifier_dropout": 0.0,
#   "d_ff": 2816,
#   "d_kv": 64,
#   "d_model": 1024,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "gelu_new",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "gated-gelu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 24,
#   "num_heads": 16,
#   "num_layers": 24,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "tie_word_embeddings": false,
#   "transformers_version": "4.46.1",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# WARNING:parler_tts.modeling_parler_tts:Config of the audio_encoder: <class 'transformers.models.dac.modeling_dac.DacModel'> is overwritten by shared audio_encoder config: DacConfig {
#   "_name_or_path": "ylacombe/dac_44khz",
#   "architectures": [
#     "DacModel"
#   ],
#   "codebook_dim": 8,
#   "codebook_loss_weight": 1.0,
#   "codebook_size": 1024,
#   "commitment_loss_weight": 0.25,
#   "decoder_hidden_size": 1536,
#   "downsampling_ratios": [
#     2,
#     4,
#     8,
#     8
#   ],
#   "encoder_hidden_size": 64,
#   "hidden_size": 1024,
#   "hop_length": 512,
#   "model_type": "dac",
#   "n_codebooks": 9,
#   "quantizer_dropout": 0.0,
#   "sampling_rate": 44100,
#   "torch_dtype": "float32",
#   "transformers_version": "4.46.1",
#   "upsampling_ratios": [
#     8,
#     8,
#     4,
#     2
#   ]
# }
#
# WARNING:parler_tts.modeling_parler_tts:Config of the decoder: <class 'parler_tts.modeling_parler_tts.ParlerTTSForCausalLM'> is overwritten by shared decoder config: ParlerTTSDecoderConfig {
#   "_name_or_path": "/fsx/yoach/tmp/artefacts/parler-tts-mini-v2-empty/decoder",
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_cross_attention": true,
#   "architectures": [
#     "ParlerTTSForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 1025,
#   "codebook_weights": null,
#   "cross_attention_implementation_strategy": null,
#   "delay_strategy": "delay",
#   "dropout": 0.1,
#   "eos_token_id": 1024,
#   "ffn_dim": 4096,
#   "hidden_size": 1024,
#   "initializer_factor": 0.02,
#   "is_decoder": true,
#   "layerdrop": 0.0,
#   "max_position_embeddings": 4096,
#   "model_type": "parler_tts_decoder",
#   "num_attention_heads": 16,
#   "num_codebooks": 9,
#   "num_cross_attention_key_value_heads": 16,
#   "num_hidden_layers": 24,
#   "num_key_value_heads": 16,
#   "pad_token_id": 1024,
#   "rope_embeddings": false,
#   "rope_theta": 10000.0,
#   "scale_embedding": false,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float32",
#   "transformers_version": "4.46.1",
#   "use_cache": true,
#   "use_fused_lm_heads": true,
#   "vocab_size": 1088
# }
#
# WARNING:parler_tts.modeling_parler_tts:Config of the text_encoder: <class 'transformers.models.t5.modeling_t5.T5EncoderModel'> is overwritten by shared text_encoder config: T5Config {
#   "_name_or_path": "google/flan-t5-large",
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "classifier_dropout": 0.0,
#   "d_ff": 2816,
#   "d_kv": 64,
#   "d_model": 1024,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "gelu_new",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "gated-gelu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 24,
#   "num_heads": 16,
#   "num_layers": 24,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "tie_word_embeddings": false,
#   "transformers_version": "4.46.1",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# WARNING:parler_tts.modeling_parler_tts:Config of the audio_encoder: <class 'transformers.models.dac.modeling_dac.DacModel'> is overwritten by shared audio_encoder config: DacConfig {
#   "_name_or_path": "ylacombe/dac_44khz",
#   "architectures": [
#     "DacModel"
#   ],
#   "codebook_dim": 8,
#   "codebook_loss_weight": 1.0,
#   "codebook_size": 1024,
#   "commitment_loss_weight": 0.25,
#   "decoder_hidden_size": 1536,
#   "downsampling_ratios": [
#     2,
#     4,
#     8,
#     8
#   ],
#   "encoder_hidden_size": 64,
#   "hidden_size": 1024,
#   "hop_length": 512,
#   "model_type": "dac",
#   "n_codebooks": 9,
#   "quantizer_dropout": 0.0,
#   "sampling_rate": 44100,
#   "torch_dtype": "float32",
#   "transformers_version": "4.46.1",
#   "upsampling_ratios": [
#     8,
#     8,
#     4,
#     2
#   ]
# }
#
# WARNING:parler_tts.modeling_parler_tts:Config of the decoder: <class 'parler_tts.modeling_parler_tts.ParlerTTSForCausalLM'> is overwritten by shared decoder config: ParlerTTSDecoderConfig {
#   "_name_or_path": "/fsx/yoach/tmp/artefacts/parler-tts-mini-v2-empty/decoder",
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_cross_attention": true,
#   "architectures": [
#     "ParlerTTSForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 1025,
#   "codebook_weights": null,
#   "cross_attention_implementation_strategy": null,
#   "delay_strategy": "delay",
#   "dropout": 0.1,
#   "eos_token_id": 1024,
#   "ffn_dim": 4096,
#   "hidden_size": 1024,
#   "initializer_factor": 0.02,
#   "is_decoder": true,
#   "layerdrop": 0.0,
#   "max_position_embeddings": 4096,
#   "model_type": "parler_tts_decoder",
#   "num_attention_heads": 16,
#   "num_codebooks": 9,
#   "num_cross_attention_key_value_heads": 16,
#   "num_hidden_layers": 24,
#   "num_key_value_heads": 16,
#   "pad_token_id": 1024,
#   "rope_embeddings": false,
#   "rope_theta": 10000.0,
#   "scale_embedding": false,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float32",
#   "transformers_version": "4.46.1",
#   "use_cache": true,
#   "use_fused_lm_heads": true,
#   "vocab_size": 1088
# }
# [tts] shard 3/4: 4,513 sentences, 0 already synthesized, 4,513 to go
# [tts] model sampling rate 44100 Hz -> resampling to 16000 Hz
# [tts] shard 2/4: 4,513 sentences, 0 already synthesized, 4,513 to go
# [tts] model sampling rate 44100 Hz -> resampling to 16000 Hz
# tts:   0%|          | 0/283 [00:00<?, ?batch/s]WARNING:parler_tts.modeling_parler_tts:`prompt_attention_mask` is specified but `attention_mask` is not. A full `attention_mask` will be created. Make sure this is the intended behaviour.
# WARNING:parler_tts.modeling_parler_tts:`prompt_attention_mask` is specified but `attention_mask` is not. A full `attention_mask` will be created. Make sure this is the intended behaviour.
# tts: 100%|██████████| 283/283 [1:11:09<00:00, 15.09s/batch]
# [tts] shard 2: wrote 4,503 clips (6.01 h), dropped 10
# tts: 100%|██████████| 283/283 [1:12:45<00:00, 15.43s/batch]
# [tts] shard 3: wrote 4,502 clips (6.03 h), dropped 11

# %% [markdown]
# ## 3 · Merge shards, build Train_T1 by reference
#
# ### GATE 2 — `Train_T1 ⊆ Train_T2`, durations ≈ 8h / 22h

# %%
merged = list(itertools.chain.from_iterable(
    read_jsonl(MAN / f"train_t2.shard{i}.jsonl") for i in range(NUM_SHARDS)
))
write_jsonl(MAN / "train_t2.jsonl", merged)
hours = sum(r["dur"] for r in merged) / 3600
print(f"Train_T2: {len(merged):,} clips, {hours:.2f} h (paper: 22 h)")

run("csasr.tts.make_subset", "--t2", MAN / "train_t2.jsonl",
    "--out", WORK / "t1_ids.json", "--hours", "8.0")
# Out:
# Train_T2: 18,010 clips, 23.95 h (paper: 22 h)
# > csasr.tts.make_subset --t2 /kaggle/working/manifests/train_t2.jsonl --out /kaggle/working/t1_ids.json --hours 8.0
# [subset] Train_T2: 18,010 clips, 23.95 h, 5,387 bigrams
# [subset] Train_T1: 6,069 clips, 8.00 h, 5,387 bigrams (100% bigram coverage)
# [subset] wrote /kaggle/working/t1_ids.json

# %% [markdown]
# ### Listen to it. Two clips per voice — do not skip this.

# %%
import IPython.display as ipd, random
from csasr.tts.speakers import assign_speaker
random.seed(0)
for voice in ("Rohit", "Divya"):
    picks = [r for r in merged if assign_speaker(r["sent_id"]).name == voice][:200]
    for r in random.sample(picks, 2):
        print(f"[{voice}] {r['text']}")
        ipd.display(ipd.Audio(r["wav"]))
# Out:
# [Rohit] उसका अजीब behavior देखकर मुझे बहुत हैरानी हुई।
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# [Rohit] आजकल के वर्क फ्रॉम होम के लिए अच्छी इंटरनेट bandwidth होना बहुत ज़रूरी है।
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# [Divya] Please ask your manager for super अनुमति before starting this project.
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# [Divya] You need to learn how to use the correct command चलाने के लिए।
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 4 · Push the synthetic corpus
#
# Parquet + FLAC ≈ 1.4 GB (vs 2.5 GB as WAV). The round-trip check catches a corrupted upload *before* a 3h training run.

# %%
run("csasr.data.push_to_hub", "--manifest", MAN / "train_t2.jsonl",
    "--repo", SYNTH_REPO, "--config", "synth_t2", "--verify")

from huggingface_hub import HfApi
HfApi().upload_file(path_or_fileobj=str(WORK / "t1_ids.json"),
                    path_in_repo="t1_ids.json", repo_id=SYNTH_REPO,
                    repo_type="dataset", token=HF_TOKEN)
print("done ->", SYNTH_REPO, "\nnext: 02_train.ipynb")
# Out:
# > csasr.data.push_to_hub --manifest /kaggle/working/manifests/train_t2.jsonl --repo RohanRamesh/hi-en-synth-cs --config synth_t2 --verify
# [push] /kaggle/working/manifests/train_t2.jsonl -> RohanRamesh/hi-en-synth-cs:synth_t2  (18,010 rows, audio=True)
# Uploading the dataset shards:   0%|          | 0/6 [00:00<?, ?it/s]
# Map:   0%|          | 0/3002 [00:00<?, ? examples/s]
# Map:   7%|▋         | 200/3002 [00:00<00:01, 1923.86 examples/s]
# Map:  17%|█▋        | 500/3002 [00:00<00:01, 1722.71 examples/s]
# Map:  30%|██▉       | 900/3002 [00:00<00:00, 2406.16 examples/s]
# Map:  40%|███▉      | 1200/3002 [00:00<00:00, 2007.57 examples/s]
# Map:  53%|█████▎    | 1600/3002 [00:00<00:00, 2397.51 examples/s]
# Map:  63%|██████▎   | 1900/3002 [00:01<00:00, 1569.71 examples/s]
# Map:  77%|███████▋  | 2300/3002 [00:01<00:00, 1944.09 examples/s]
# Map: 100%|██████████| 3002/3002 [00:01<00:00, 2187.19 examples/s]
#
# Creating parquet from Arrow format:   0%|          | 0/31 [00:00<?, ?ba/s]
# Creating parquet from Arrow format:  10%|▉         | 3/31 [00:00<00:01, 26.47ba/s]
# Creating parquet from Arrow format:  19%|█▉        | 6/31 [00:00<00:00, 25.80ba/s]
# Creating parquet from Arrow format:  29%|██▉       | 9/31 [00:00<00:00, 25.99ba/s]
# Creating parquet from Arrow format:  39%|███▊      | 12/31 [00:00<00:00, 25.00ba/s]
# Creating parquet from Arrow format:  48%|████▊     | 15/31 [00:00<00:00, 24.83ba/s]
# Creating parquet from Arrow format:  58%|█████▊    | 18/31 [00:00<00:00, 22.92ba/s]
# Creating parquet from Arrow format:  68%|██████▊   | 21/31 [00:00<00:00, 23.10ba/s]
# Creating parquet from Arrow format:  77%|███████▋  | 24/31 [00:00<00:00, 24.09ba/s]
# Creating parquet from Arrow format:  87%|████████▋ | 27/31 [00:01<00:00, 24.12ba/s]
# Creating parquet from Arrow format: 100%|██████████| 31/31 [00:01<00:00, 25.31ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#                               :   0%|          |  583kB /  401MB
#
# Processing Files (0 / 1)      :   0%|          |  583kB /  401MB,  972kB/s
# New Data Upload               :   1%|          |  583kB / 67.1MB,  972kB/s
#
# Processing Files (0 / 1)      :   6%|▋         | 25.7MB /  401MB, 32.1MB/s
# New Data Upload               :  19%|█▉        | 25.7MB /  134MB, 32.1MB/s
#
# Processing Files (0 / 1)      :  15%|█▍        | 58.9MB /  401MB, 58.9MB/s
# New Data Upload               :  44%|████▍     | 58.9MB /  134MB, 58.9MB/s
#
# Processing Files (0 / 1)      :  17%|█▋        | 67.1MB /  401MB, 55.9MB/s
# New Data Upload               :  50%|█████     | 67.1MB /  134MB, 55.9MB/s
#
#                               :  17%|█▋        | 67.1MB /  401MB
#
#                               :  17%|█▋        | 67.1MB /  401MB
#
# Processing Files (0 / 1)      :  17%|█▋        | 67.1MB /  401MB, 37.3MB/s
# New Data Upload               :  50%|█████     | 67.1MB /  134MB, 37.3MB/s
#
# Processing Files (0 / 1)      :  21%|██▏       | 85.2MB /  401MB, 42.6MB/s
# New Data Upload               :  63%|██████▎   | 85.2MB /  134MB, 42.6MB/s
#
# Processing Files (0 / 1)      :  29%|██▉       |  116MB /  401MB, 52.5MB/s
# New Data Upload               :  57%|█████▋    |  116MB /  201MB, 52.5MB/s
#
# Processing Files (0 / 1)      :  33%|███▎      |  134MB /  401MB, 55.7MB/s
# New Data Upload               :  66%|██████▋   |  134MB /  201MB, 55.7MB/s
#
# Processing Files (0 / 1)      :  34%|███▍      |  137MB /  401MB, 52.6MB/s
# New Data Upload               :  68%|██████▊   |  137MB /  201MB, 52.6MB/s
#
# Processing Files (0 / 1)      :  43%|████▎     |  171MB /  401MB, 61.2MB/s
# New Data Upload               :  64%|██████▍   |  171MB /  268MB, 61.2MB/s
#
# Processing Files (0 / 1)      :  50%|█████     |  201MB /  401MB, 66.8MB/s
# New Data Upload               :  75%|███████▍  |  201MB /  268MB, 66.8MB/s
#
# Processing Files (0 / 1)      :  58%|█████▊    |  234MB /  401MB, 73.2MB/s
# New Data Upload               :  87%|████████▋ |  234MB /  268MB, 73.2MB/s
#
# Processing Files (0 / 1)      :  67%|██████▋   |  268MB /  401MB, 78.8MB/s
# New Data Upload               :  80%|███████▉  |  268MB /  335MB, 78.8MB/s
#
# Processing Files (0 / 1)      :  67%|██████▋   |  268MB /  401MB, 74.5MB/s
# New Data Upload               :  80%|████████  |  268MB /  335MB, 74.5MB/s
#
# Processing Files (0 / 1)      :  73%|███████▎  |  293MB /  401MB, 77.0MB/s
# New Data Upload               :  73%|███████▎  |  293MB /  401MB, 77.0MB/s
#
# Processing Files (0 / 1)      :  83%|████████▎ |  334MB /  401MB, 83.6MB/s
# New Data Upload               :  83%|████████▎ |  334MB /  401MB, 83.6MB/s
#
# Processing Files (0 / 1)      :  84%|████████▍ |  336MB /  401MB, 79.9MB/s
# New Data Upload               :  84%|████████▍ |  336MB /  401MB, 79.9MB/s
#
# Processing Files (0 / 1)      :  91%|█████████▏|  366MB /  401MB, 83.2MB/s
# New Data Upload               :  91%|█████████▏|  366MB /  401MB, 83.2MB/s
#
# Processing Files (0 / 1)      : 100%|█████████▉|  400MB /  401MB, 86.9MB/s
# New Data Upload               : 100%|█████████▉|  400MB /  401MB, 86.9MB/s
#
# Processing Files (0 / 1)      : 100%|█████████▉|  400MB /  401MB, 83.4MB/s
# New Data Upload               : 100%|█████████▉|  400MB /  401MB, 83.4MB/s
#
#                               : 100%|█████████▉|  400MB /  401MB
#
#                               : 100%|█████████▉|  400MB /  401MB
#
# Processing Files (1 / 1)      : 100%|██████████|  401MB /  401MB, 74.3MB/s
# New Data Upload               : 100%|██████████|  401MB /  401MB, 74.3MB/s
#
#                               : 100%|██████████|  401MB /  401MB
#
#                               : 100%|██████████|  401MB /  401MB
#
# Processing Files (1 / 1)      : 100%|██████████|  401MB /  401MB, 69.1MB/s
# New Data Upload               : 100%|██████████|  401MB /  401MB, 69.1MB/s
#                               : 100%|██████████|  401MB /  401MB
# Uploading the dataset shards:  17%|█▋        | 1/6 [00:15<01:16, 15.38s/it]
# Map:   0%|          | 0/3002 [00:00<?, ? examples/s]
# Map:   7%|▋         | 200/3002 [00:00<00:01, 1670.68 examples/s]
# Map:  17%|█▋        | 500/3002 [00:00<00:01, 1763.59 examples/s]
# Map:  30%|██▉       | 900/3002 [00:00<00:01, 1768.47 examples/s]
# Map:  43%|████▎     | 1300/3002 [00:00<00:00, 2258.66 examples/s]
# Map:  60%|█████▉    | 1800/3002 [00:00<00:00, 1800.39 examples/s]
# Map:  73%|███████▎  | 2200/3002 [00:01<00:00, 2020.04 examples/s]
# Map:  87%|████████▋ | 2600/3002 [00:01<00:00, 2304.80 examples/s]
# Map: 100%|██████████| 3002/3002 [00:01<00:00, 2165.63 examples/s]
#
# Creating parquet from Arrow format:   0%|          | 0/31 [00:00<?, ?ba/s]
# Creating parquet from Arrow format:  10%|▉         | 3/31 [00:00<00:01, 25.01ba/s]
# Creating parquet from Arrow format:  19%|█▉        | 6/31 [00:00<00:00, 25.81ba/s]
# Creating parquet from Arrow format:  29%|██▉       | 9/31 [00:00<00:00, 24.87ba/s]
# Creating parquet from Arrow format:  39%|███▊      | 12/31 [00:00<00:00, 24.81ba/s]
# Creating parquet from Arrow format:  48%|████▊     | 15/31 [00:00<00:00, 24.66ba/s]
# Creating parquet from Arrow format:  58%|█████▊    | 18/31 [00:00<00:00, 24.71ba/s]
# Creating parquet from Arrow format:  68%|██████▊   | 21/31 [00:00<00:00, 25.02ba/s]
# Creating parquet from Arrow format:  77%|███████▋  | 24/31 [00:00<00:00, 25.17ba/s]
# Creating parquet from Arrow format:  87%|████████▋ | 27/31 [00:01<00:00, 25.16ba/s]
# Creating parquet from Arrow format: 100%|██████████| 31/31 [00:01<00:00, 25.50ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#                               :   2%|▏         | 10.1MB /  416MB
#
# Processing Files (0 / 1)      :   2%|▏         | 10.1MB /  416MB, 16.8MB/s
# New Data Upload               :   8%|▊         | 10.1MB /  134MB, 16.8MB/s
#
# Processing Files (0 / 1)      :  11%|█         | 45.2MB /  416MB, 56.4MB/s
# New Data Upload               :  34%|███▎      | 45.2MB /  134MB, 56.4MB/s
#
# Processing Files (0 / 1)      :  16%|█▌        | 66.6MB /  416MB, 66.5MB/s
# New Data Upload               :  50%|████▉     | 66.6MB /  134MB, 66.5MB/s
#
#                               :  16%|█▌        | 66.6MB /  416MB
#
#                               :  16%|█▌        | 66.6MB /  416MB
#
# Processing Files (0 / 1)      :  16%|█▌        | 67.0MB /  416MB, 41.9MB/s
# New Data Upload               :  50%|████▉     | 67.0MB /  134MB, 41.9MB/s
#
# Processing Files (0 / 1)      :  21%|██        | 86.9MB /  416MB, 48.3MB/s
# New Data Upload               :  65%|██████▍   | 86.9MB /  134MB, 48.3MB/s
#
# Processing Files (0 / 1)      :  31%|███       |  128MB /  416MB, 64.2MB/s
# New Data Upload               :  64%|██████▍   |  128MB /  201MB, 64.2MB/s
#
# Processing Files (0 / 1)      :  32%|███▏      |  134MB /  416MB, 60.8MB/s
# New Data Upload               :  67%|██████▋   |  134MB /  201MB, 60.8MB/s
#
# Processing Files (0 / 1)      :  35%|███▌      |  146MB /  416MB, 61.0MB/s
# New Data Upload               :  55%|█████▍    |  146MB /  268MB, 61.0MB/s
#
# Processing Files (0 / 1)      :  46%|████▌     |  190MB /  416MB, 73.1MB/s
# New Data Upload               :  71%|███████   |  190MB /  268MB, 73.1MB/s
#
# Processing Files (0 / 1)      :  50%|████▉     |  207MB /  416MB, 74.1MB/s
# New Data Upload               :  77%|███████▋  |  207MB /  268MB, 74.1MB/s
#
# Processing Files (0 / 1)      :  57%|█████▋    |  237MB /  416MB, 79.1MB/s
# New Data Upload               :  71%|███████   |  237MB /  335MB, 79.1MB/s
#
# Processing Files (0 / 1)      :  65%|██████▌   |  272MB /  416MB, 85.0MB/s
# New Data Upload               :  81%|████████  |  272MB /  335MB, 85.0MB/s
#
# Processing Files (0 / 1)      :  74%|███████▎  |  306MB /  416MB, 89.9MB/s
# New Data Upload               :  91%|█████████ |  306MB /  335MB, 89.9MB/s
#
# Processing Files (0 / 1)      :  81%|████████  |  335MB /  416MB, 93.1MB/s
# New Data Upload               :  83%|████████▎ |  335MB /  402MB, 93.1MB/s
#
# Processing Files (0 / 1)      :  83%|████████▎ |  346MB /  416MB, 91.1MB/s
# New Data Upload               :  83%|████████▎ |  346MB /  416MB, 91.1MB/s
#
# Processing Files (0 / 1)      :  94%|█████████▍|  392MB /  416MB, 97.9MB/s
# New Data Upload               :  94%|█████████▍|  392MB /  416MB, 97.9MB/s
#
# Processing Files (0 / 1)      : 100%|█████████▉|  415MB /  416MB, 98.8MB/s
# New Data Upload               : 100%|█████████▉|  415MB /  416MB, 98.8MB/s
#
# Processing Files (0 / 1)      : 100%|█████████▉|  416MB /  416MB, 94.5MB/s
# New Data Upload               : 100%|█████████▉|  416MB /  416MB, 94.5MB/s
#
#                               : 100%|█████████▉|  416MB /  416MB
#
#                               : 100%|█████████▉|  416MB /  416MB
#
# Processing Files (1 / 1)      : 100%|██████████|  416MB /  416MB, 83.2MB/s
# New Data Upload               : 100%|██████████|  416MB /  416MB, 83.2MB/s
#
#                               : 100%|██████████|  416MB /  416MB
#
#                               : 100%|██████████|  416MB /  416MB
#
# Processing Files (1 / 1)      : 100%|██████████|  416MB /  416MB, 77.0MB/s
# New Data Upload               : 100%|██████████|  416MB /  416MB, 77.0MB/s
#                               : 100%|██████████|  416MB /  416MB
# Uploading the dataset shards:  33%|███▎      | 2/6 [00:30<01:01, 15.28s/it]
# Map:   0%|          | 0/3002 [00:00<?, ? examples/s]
# Map:  10%|▉         | 300/3002 [00:00<00:00, 2884.50 examples/s]
# Map:  23%|██▎       | 700/3002 [00:00<00:00, 2566.15 examples/s]
# Map:  33%|███▎      | 1000/3002 [00:00<00:00, 2048.54 examples/s]
# Map:  47%|████▋     | 1400/3002 [00:00<00:00, 2546.41 examples/s]
# Map:  60%|█████▉    | 1800/3002 [00:00<00:00, 1813.27 examples/s]
# Map:  73%|███████▎  | 2200/3002 [00:00<00:00, 2201.54 examples/s]
# Map:  87%|████████▋ | 2600/3002 [00:01<00:00, 2511.49 examples/s]
# Map: 100%|██████████| 3002/3002 [00:01<00:00, 2428.16 examples/s]
#
# Creating parquet from Arrow format:   0%|          | 0/31 [00:00<?, ?ba/s]
# Creating parquet from Arrow format:  10%|▉         | 3/31 [00:00<00:01, 25.98ba/s]
# Creating parquet from Arrow format:  19%|█▉        | 6/31 [00:00<00:00, 26.12ba/s]
# Creating parquet from Arrow format:  29%|██▉       | 9/31 [00:00<00:00, 26.40ba/s]
# Creating parquet from Arrow format:  39%|███▊      | 12/31 [00:00<00:00, 26.02ba/s]
# Creating parquet from Arrow format:  48%|████▊     | 15/31 [00:00<00:00, 26.50ba/s]
# Creating parquet from Arrow format:  58%|█████▊    | 18/31 [00:00<00:00, 25.81ba/s]
# Creating parquet from Arrow format:  68%|██████▊   | 21/31 [00:00<00:00, 25.66ba/s]
# Creating parquet from Arrow format:  77%|███████▋  | 24/31 [00:00<00:00, 25.31ba/s]
# Creating parquet from Arrow format:  87%|████████▋ | 27/31 [00:01<00:00, 18.51ba/s]
# Creating parquet from Arrow format: 100%|██████████| 31/31 [00:01<00:00, 23.25ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#                               :   2%|▏         | 6.47MB /  410MB
#
# Processing Files (0 / 1)      :   2%|▏         | 6.47MB /  410MB, 10.8MB/s
# New Data Upload               :  10%|▉         | 6.47MB / 67.1MB, 10.8MB/s
#
# Processing Files (0 / 1)      :  12%|█▏        | 47.6MB /  410MB, 59.6MB/s
# New Data Upload               :  36%|███▌      | 47.6MB /  134MB, 59.6MB/s
#
# Processing Files (0 / 1)      :  16%|█▋        | 67.0MB /  410MB, 67.0MB/s
# New Data Upload               :  50%|████▉     | 67.0MB /  134MB, 67.0MB/s
#
#                               :  16%|█▋        | 67.0MB /  410MB
#
#                               :  16%|█▋        | 67.0MB /  410MB
#
#                               :  16%|█▋        | 67.0MB /  410MB
#
# Processing Files (0 / 1)      :  19%|█▉        | 78.6MB /  410MB, 43.6MB/s
# New Data Upload               :  59%|█████▊    | 78.6MB /  134MB, 43.6MB/s
#
# Processing Files (0 / 1)      :  30%|███       |  124MB /  410MB, 62.1MB/s
# New Data Upload               :  62%|██████▏   |  124MB /  201MB, 62.1MB/s
#
# Processing Files (0 / 1)      :  33%|███▎      |  134MB /  410MB, 60.9MB/s
# New Data Upload               :  67%|██████▋   |  134MB /  201MB, 60.9MB/s
#
# Processing Files (0 / 1)      :  34%|███▍      |  141MB /  410MB, 58.6MB/s
# New Data Upload               :  70%|██████▉   |  141MB /  201MB, 58.6MB/s
#
# Processing Files (0 / 1)      :  43%|████▎     |  177MB /  410MB, 68.1MB/s
# New Data Upload               :  66%|██████▌   |  177MB /  268MB, 68.1MB/s
#
# Processing Files (0 / 1)      :  50%|████▉     |  205MB /  410MB, 73.1MB/s
# New Data Upload               :  76%|███████▋  |  205MB /  268MB, 73.1MB/s
#
# Processing Files (0 / 1)      :  54%|█████▍    |  221MB /  410MB, 73.7MB/s
# New Data Upload               :  66%|██████▌   |  221MB /  335MB, 73.7MB/s
#
# Processing Files (0 / 1)      :  65%|██████▍   |  266MB /  410MB, 83.2MB/s
# New Data Upload               :  79%|███████▉  |  266MB /  335MB, 83.2MB/s
#
# Processing Files (0 / 1)      :  70%|██████▉   |  287MB /  410MB, 84.4MB/s
# New Data Upload               :  86%|████████▌ |  287MB /  335MB, 84.4MB/s
#
# Processing Files (0 / 1)      :  80%|████████  |  328MB /  410MB, 91.2MB/s
# New Data Upload               :  82%|████████▏ |  328MB /  402MB, 91.2MB/s
#
# Processing Files (0 / 1)      :  83%|████████▎ |  339MB /  410MB, 89.3MB/s
# New Data Upload               :  83%|████████▎ |  339MB /  410MB, 89.3MB/s
#
# Processing Files (0 / 1)      :  88%|████████▊ |  359MB /  410MB, 89.8MB/s
# New Data Upload               :  88%|████████▊ |  359MB /  410MB, 89.8MB/s
#
# Processing Files (0 / 1)      :  96%|█████████▋|  395MB /  410MB, 94.0MB/s
# New Data Upload               :  96%|█████████▋|  395MB /  410MB, 94.0MB/s
#
# Processing Files (0 / 1)      : 100%|█████████▉|  410MB /  410MB, 93.1MB/s
# New Data Upload               : 100%|█████████▉|  410MB /  410MB, 93.1MB/s
#
#                               : 100%|█████████▉|  410MB /  410MB
#
#                               : 100%|█████████▉|  410MB /  410MB
#
# Processing Files (1 / 1)      : 100%|██████████|  410MB /  410MB, 82.0MB/s
# New Data Upload               : 100%|██████████|  410MB /  410MB, 82.0MB/s
#
#                               : 100%|██████████|  410MB /  410MB
#
#                               : 100%|██████████|  410MB /  410MB
#
# Processing Files (1 / 1)      : 100%|██████████|  410MB /  410MB, 75.9MB/s
# New Data Upload               : 100%|██████████|  410MB /  410MB, 75.9MB/s
#                               : 100%|██████████|  410MB /  410MB
# Uploading the dataset shards:  50%|█████     | 3/6 [00:45<00:45, 15.24s/it]
# Map:   0%|          | 0/3002 [00:00<?, ? examples/s]
# Map:  10%|▉         | 300/3002 [00:00<00:01, 2445.04 examples/s]
# Map:  23%|██▎       | 700/3002 [00:00<00:00, 2354.41 examples/s]
# Map:  37%|███▋      | 1100/3002 [00:00<00:00, 2092.40 examples/s]
# Map:  50%|████▉     | 1500/3002 [00:00<00:00, 2514.92 examples/s]
# Map:  60%|█████▉    | 1800/3002 [00:00<00:00, 1751.97 examples/s]
# Map:  73%|███████▎  | 2200/3002 [00:01<00:00, 2165.68 examples/s]
# Map:  87%|████████▋ | 2600/3002 [00:01<00:00, 2492.01 examples/s]
# Map: 100%|██████████| 3002/3002 [00:01<00:00, 2403.11 examples/s]
#
# Creating parquet from Arrow format:   0%|          | 0/31 [00:00<?, ?ba/s]
# Creating parquet from Arrow format:  10%|▉         | 3/31 [00:00<00:01, 23.29ba/s]
# Creating parquet from Arrow format:  19%|█▉        | 6/31 [00:00<00:01, 24.13ba/s]
# Creating parquet from Arrow format:  29%|██▉       | 9/31 [00:00<00:00, 24.90ba/s]
# Creating parquet from Arrow format:  39%|███▊      | 12/31 [00:00<00:00, 25.35ba/s]
# Creating parquet from Arrow format:  48%|████▊     | 15/31 [00:00<00:00, 25.08ba/s]
# Creating parquet from Arrow format:  58%|█████▊    | 18/31 [00:00<00:00, 25.46ba/s]
# Creating parquet from Arrow format:  68%|██████▊   | 21/31 [00:00<00:00, 25.68ba/s]
# Creating parquet from Arrow format:  77%|███████▋  | 24/31 [00:00<00:00, 25.57ba/s]
# Creating parquet from Arrow format:  87%|████████▋ | 27/31 [00:01<00:00, 25.32ba/s]
# Creating parquet from Arrow format: 100%|██████████| 31/31 [00:01<00:00, 26.10ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#                               :   2%|▏         | 8.18MB /  405MB
#
# Processing Files (0 / 1)      :   2%|▏         | 8.18MB /  405MB, 13.6MB/s
# New Data Upload               :  12%|█▏        | 8.18MB / 67.1MB, 13.6MB/s
#
# Processing Files (0 / 1)      :  11%|█▏        | 46.1MB /  405MB, 57.7MB/s
# New Data Upload               :  34%|███▍      | 46.1MB /  134MB, 57.7MB/s
#
# Processing Files (0 / 1)      :  16%|█▋        | 66.6MB /  405MB, 66.5MB/s
# New Data Upload               :  50%|████▉     | 66.6MB /  134MB, 66.5MB/s
#
#                               :  16%|█▋        | 66.6MB /  405MB
#
#                               :  16%|█▋        | 66.6MB /  405MB
#
#                               :  16%|█▋        | 66.6MB /  405MB
#
# Processing Files (0 / 1)      :  18%|█▊        | 71.3MB /  405MB, 39.6MB/s
# New Data Upload               :  53%|█████▎    | 71.3MB /  134MB, 39.6MB/s
#
# Processing Files (0 / 1)      :  27%|██▋       |  111MB /  405MB, 55.2MB/s
# New Data Upload               :  82%|████████▏ |  111MB /  134MB, 55.2MB/s
#
# Processing Files (0 / 1)      :  33%|███▎      |  134MB /  405MB, 60.8MB/s
# New Data Upload               :  66%|██████▋   |  134MB /  201MB, 60.8MB/s
#
# Processing Files (0 / 1)      :  34%|███▍      |  138MB /  405MB, 57.4MB/s
# New Data Upload               :  68%|██████▊   |  138MB /  201MB, 57.4MB/s
#
# Processing Files (0 / 1)      :  41%|████      |  164MB /  405MB, 63.2MB/s
# New Data Upload               :  61%|██████▏   |  164MB /  268MB, 63.2MB/s
#
# Processing Files (0 / 1)      :  49%|████▉     |  200MB /  405MB, 71.6MB/s
# New Data Upload               :  75%|███████▍  |  200MB /  268MB, 71.6MB/s
#
# Processing Files (0 / 1)      :  52%|█████▏    |  209MB /  405MB, 69.7MB/s
# New Data Upload               :  78%|███████▊  |  209MB /  268MB, 69.7MB/s
#
# Processing Files (0 / 1)      :  61%|██████    |  247MB /  405MB, 77.2MB/s
# New Data Upload               :  74%|███████▎  |  247MB /  335MB, 77.2MB/s
#
# Processing Files (0 / 1)      :  67%|██████▋   |  272MB /  405MB, 80.0MB/s
# New Data Upload               :  81%|████████  |  272MB /  335MB, 80.0MB/s
#
# Processing Files (0 / 1)      :  74%|███████▍  |  299MB /  405MB, 83.0MB/s
# New Data Upload               :  74%|███████▍  |  299MB /  403MB, 83.0MB/s
#
# Processing Files (0 / 1)      :  82%|████████▏ |  333MB /  405MB, 87.6MB/s
# New Data Upload               :  83%|████████▎ |  333MB /  403MB, 87.6MB/s
#
# Processing Files (0 / 1)      :  84%|████████▍ |  342MB /  405MB, 85.4MB/s
# New Data Upload               :  84%|████████▍ |  342MB /  405MB, 85.4MB/s
#
# Processing Files (0 / 1)      :  91%|█████████ |  368MB /  405MB, 87.6MB/s
# New Data Upload               :  91%|█████████ |  368MB /  405MB, 87.6MB/s
#
# Processing Files (0 / 1)      :  99%|█████████▉|  402MB /  405MB, 91.4MB/s
# New Data Upload               :  99%|█████████▉|  402MB /  405MB, 91.4MB/s
#
# Processing Files (0 / 1)      : 100%|█████████▉|  405MB /  405MB, 87.9MB/s
# New Data Upload               : 100%|█████████▉|  405MB /  405MB, 87.9MB/s
#
# Processing Files (0 / 1)      : 100%|█████████▉|  405MB /  405MB, 84.3MB/s
# New Data Upload               : 100%|█████████▉|  405MB /  405MB, 84.3MB/s
#
#                               : 100%|█████████▉|  405MB /  405MB
#
# Processing Files (1 / 1)      : 100%|██████████|  405MB /  405MB, 77.9MB/s
# New Data Upload               : 100%|██████████|  405MB /  405MB, 77.9MB/s
#
#                               : 100%|██████████|  405MB /  405MB
#
#                               : 100%|██████████|  405MB /  405MB
#
# Processing Files (1 / 1)      : 100%|██████████|  405MB /  405MB, 72.4MB/s
# New Data Upload               : 100%|██████████|  405MB /  405MB, 72.4MB/s
#                               : 100%|██████████|  405MB /  405MB
# Uploading the dataset shards:  67%|██████▋   | 4/6 [01:00<00:30, 15.21s/it]
# Map:   0%|          | 0/3001 [00:00<?, ? examples/s]
# Map:  17%|█▋        | 500/3001 [00:00<00:00, 2951.99 examples/s]
# Map:  30%|██▉       | 900/3001 [00:00<00:00, 3077.81 examples/s]
# Map:  50%|████▉     | 1500/3001 [00:00<00:00, 3964.92 examples/s]
# Map:  67%|██████▋   | 2000/3001 [00:00<00:00, 2404.74 examples/s]
# Map:  80%|███████▉  | 2400/3001 [00:00<00:00, 2691.14 examples/s]
# Map: 100%|██████████| 3001/3001 [00:01<00:00, 2931.25 examples/s]
#
# Creating parquet from Arrow format:   0%|          | 0/31 [00:00<?, ?ba/s]
# Creating parquet from Arrow format:  10%|▉         | 3/31 [00:00<00:01, 23.96ba/s]
# Creating parquet from Arrow format:  19%|█▉        | 6/31 [00:00<00:01, 24.84ba/s]
# Creating parquet from Arrow format:  29%|██▉       | 9/31 [00:00<00:00, 24.42ba/s]
# Creating parquet from Arrow format:  39%|███▊      | 12/31 [00:00<00:00, 24.31ba/s]
# Creating parquet from Arrow format:  48%|████▊     | 15/31 [00:00<00:00, 24.33ba/s]
# Creating parquet from Arrow format:  58%|█████▊    | 18/31 [00:00<00:00, 24.56ba/s]
# Creating parquet from Arrow format:  68%|██████▊   | 21/31 [00:00<00:00, 24.43ba/s]
# Creating parquet from Arrow format:  77%|███████▋  | 24/31 [00:00<00:00, 24.83ba/s]
# Creating parquet from Arrow format:  87%|████████▋ | 27/31 [00:01<00:00, 17.99ba/s]
# Creating parquet from Arrow format: 100%|██████████| 31/31 [00:01<00:00, 22.54ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#                               :   1%|          | 4.16MB /  418MB
#
# Processing Files (0 / 1)      :   1%|          | 4.16MB /  418MB, 6.92MB/s
# New Data Upload               :   6%|▌         | 4.16MB / 67.1MB, 6.92MB/s
#
# Processing Files (0 / 1)      :   9%|▉         | 38.0MB /  418MB, 47.5MB/s
# New Data Upload               :  28%|██▊       | 38.0MB /  134MB, 47.5MB/s
#
# Processing Files (0 / 1)      :  16%|█▌        | 66.5MB /  418MB, 66.5MB/s
# New Data Upload               :  50%|████▉     | 66.5MB /  134MB, 66.5MB/s
#
#                               :  16%|█▌        | 66.5MB /  418MB
#
#                               :  16%|█▌        | 66.5MB /  418MB
#
#                               :  16%|█▌        | 66.5MB /  418MB
#
# Processing Files (0 / 1)      :  16%|█▌        | 67.1MB /  418MB, 37.3MB/s
# New Data Upload               :  50%|█████     | 67.1MB /  134MB, 37.3MB/s
#
# Processing Files (0 / 1)      :  23%|██▎       | 94.6MB /  418MB, 47.3MB/s
# New Data Upload               :  71%|███████   | 94.6MB /  134MB, 47.3MB/s
#
# Processing Files (0 / 1)      :  30%|██▉       |  123MB /  418MB, 56.0MB/s
# New Data Upload               :  61%|██████    |  123MB /  201MB, 56.0MB/s
#
# Processing Files (0 / 1)      :  32%|███▏      |  134MB /  418MB, 55.7MB/s
# New Data Upload               :  66%|██████▋   |  134MB /  201MB, 55.7MB/s
#
# Processing Files (0 / 1)      :  34%|███▎      |  140MB /  418MB, 54.0MB/s
# New Data Upload               :  70%|██████▉   |  140MB /  201MB, 54.0MB/s
#
# Processing Files (0 / 1)      :  42%|████▏     |  176MB /  418MB, 62.7MB/s
# New Data Upload               :  65%|██████▌   |  176MB /  268MB, 62.7MB/s
#
# Processing Files (0 / 1)      :  49%|████▉     |  205MB /  418MB, 68.3MB/s
# New Data Upload               :  76%|███████▋  |  205MB /  268MB, 68.3MB/s
#
# Processing Files (0 / 1)      :  52%|█████▏    |  219MB /  418MB, 68.4MB/s
# New Data Upload               :  65%|██████▌   |  219MB /  335MB, 68.4MB/s
#
# Processing Files (0 / 1)      :  63%|██████▎   |  262MB /  418MB, 76.9MB/s
# New Data Upload               :  78%|███████▊  |  262MB /  335MB, 76.9MB/s
#
# Processing Files (0 / 1)      :  66%|██████▌   |  275MB /  418MB, 76.3MB/s
# New Data Upload               :  82%|████████▏ |  275MB /  335MB, 76.3MB/s
#
# Processing Files (0 / 1)      :  75%|███████▍  |  312MB /  418MB, 82.1MB/s
# New Data Upload               :  78%|███████▊  |  312MB /  402MB, 82.1MB/s
#
# Processing Files (0 / 1)      :  80%|████████  |  335MB /  418MB, 83.7MB/s
# New Data Upload               :  83%|████████▎ |  335MB /  402MB, 83.7MB/s
#
# Processing Files (0 / 1)      :  85%|████████▍ |  355MB /  418MB, 84.5MB/s
# New Data Upload               :  85%|████████▍ |  355MB /  418MB, 84.5MB/s
#
# Processing Files (0 / 1)      :  94%|█████████▍|  393MB /  418MB, 89.2MB/s
# New Data Upload               :  94%|█████████▍|  393MB /  418MB, 89.2MB/s
#
# Processing Files (0 / 1)      : 100%|█████████▉|  417MB /  418MB, 90.7MB/s
# New Data Upload               : 100%|█████████▉|  417MB /  418MB, 90.7MB/s
#
# Processing Files (0 / 1)      : 100%|█████████▉|  418MB /  418MB, 87.0MB/s
# New Data Upload               : 100%|█████████▉|  418MB /  418MB, 87.0MB/s
#
#                               : 100%|█████████▉|  418MB /  418MB
#
#                               : 100%|█████████▉|  418MB /  418MB
#
#                               : 100%|█████████▉|  418MB /  418MB
#
# Processing Files (1 / 1)      : 100%|██████████|  418MB /  418MB, 74.6MB/s
# New Data Upload               : 100%|██████████|  418MB /  418MB, 74.6MB/s
#
#                               : 100%|██████████|  418MB /  418MB
#
#                               : 100%|██████████|  418MB /  418MB
#
# Processing Files (1 / 1)      : 100%|██████████|  418MB /  418MB, 69.6MB/s
# New Data Upload               : 100%|██████████|  418MB /  418MB, 69.6MB/s
#                               : 100%|██████████|  418MB /  418MB
# Uploading the dataset shards:  83%|████████▎ | 5/6 [01:16<00:15, 15.44s/it]
# Map:   0%|          | 0/3001 [00:00<?, ? examples/s]
# Map:  10%|▉         | 300/3001 [00:00<00:01, 2697.81 examples/s]
# Map:  23%|██▎       | 700/3001 [00:00<00:00, 2506.74 examples/s]
# Map:  37%|███▋      | 1100/3001 [00:00<00:00, 2101.00 examples/s]
# Map:  50%|████▉     | 1500/3001 [00:00<00:00, 2536.57 examples/s]
# Map:  60%|█████▉    | 1800/3001 [00:00<00:00, 1733.17 examples/s]
# Map:  73%|███████▎  | 2200/3001 [00:01<00:00, 2126.92 examples/s]
# Map:  87%|████████▋ | 2600/3001 [00:01<00:00, 2425.23 examples/s]
# Map: 100%|██████████| 3001/3001 [00:01<00:00, 2384.10 examples/s]
#
# Creating parquet from Arrow format:   0%|          | 0/31 [00:00<?, ?ba/s]
# Creating parquet from Arrow format:   6%|▋         | 2/31 [00:00<00:01, 19.87ba/s]
# Creating parquet from Arrow format:  16%|█▌        | 5/31 [00:00<00:01, 23.11ba/s]
# Creating parquet from Arrow format:  26%|██▌       | 8/31 [00:00<00:01, 22.65ba/s]
# Creating parquet from Arrow format:  35%|███▌      | 11/31 [00:00<00:00, 22.89ba/s]
# Creating parquet from Arrow format:  45%|████▌     | 14/31 [00:00<00:00, 23.47ba/s]
# Creating parquet from Arrow format:  55%|█████▍    | 17/31 [00:00<00:00, 23.63ba/s]
# Creating parquet from Arrow format:  65%|██████▍   | 20/31 [00:00<00:00, 24.52ba/s]
# Creating parquet from Arrow format:  74%|███████▍  | 23/31 [00:00<00:00, 24.18ba/s]
# Creating parquet from Arrow format:  84%|████████▍ | 26/31 [00:01<00:00, 23.71ba/s]
# Creating parquet from Arrow format: 100%|██████████| 31/31 [00:01<00:00, 24.33ba/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#                               :   3%|▎         | 11.1MB /  416MB
#
# Processing Files (0 / 1)      :   3%|▎         | 11.1MB /  416MB, 18.5MB/s
# New Data Upload               :  17%|█▋        | 11.1MB / 67.1MB, 18.5MB/s
#
# Processing Files (0 / 1)      :  11%|█         | 46.7MB /  416MB, 58.3MB/s
# New Data Upload               :  35%|███▍      | 46.7MB /  134MB, 58.3MB/s
#
# Processing Files (0 / 1)      :  16%|█▌        | 66.5MB /  416MB, 66.5MB/s
# New Data Upload               :  50%|████▉     | 66.5MB /  134MB, 66.5MB/s
#
#                               :  16%|█▌        | 66.5MB /  416MB
#
#                               :  16%|█▌        | 66.5MB /  416MB
#
#                               :  16%|█▌        | 66.5MB /  416MB
#
# Processing Files (0 / 1)      :  17%|█▋        | 71.2MB /  416MB, 39.6MB/s
# New Data Upload               :  53%|█████▎    | 71.2MB /  134MB, 39.6MB/s
#
# Processing Files (0 / 1)      :  27%|██▋       |  112MB /  416MB, 55.9MB/s
# New Data Upload               :  56%|█████▌    |  112MB /  201MB, 55.9MB/s
#
# Processing Files (0 / 1)      :  32%|███▏      |  134MB /  416MB, 60.8MB/s
# New Data Upload               :  67%|██████▋   |  134MB /  201MB, 60.8MB/s
#
# Processing Files (0 / 1)      :  33%|███▎      |  138MB /  416MB, 57.5MB/s
# New Data Upload               :  69%|██████▊   |  138MB /  201MB, 57.5MB/s
#
# Processing Files (0 / 1)      :  38%|███▊      |  160MB /  416MB, 61.5MB/s
# New Data Upload               :  60%|█████▉    |  160MB /  268MB, 61.5MB/s
#
# Processing Files (0 / 1)      :  47%|████▋     |  197MB /  416MB, 70.4MB/s
# New Data Upload               :  73%|███████▎  |  197MB /  268MB, 70.4MB/s
#
# Processing Files (0 / 1)      :  50%|█████     |  209MB /  416MB, 69.7MB/s
# New Data Upload               :  78%|███████▊  |  209MB /  268MB, 69.7MB/s
#
# Processing Files (0 / 1)      :  60%|█████▉    |  248MB /  416MB, 77.4MB/s
# New Data Upload               :  74%|███████▍  |  248MB /  335MB, 77.4MB/s
#
# Processing Files (0 / 1)      :  66%|██████▌   |  274MB /  416MB, 80.5MB/s
# New Data Upload               :  82%|████████▏ |  274MB /  335MB, 80.5MB/s
#
# Processing Files (0 / 1)      :  75%|███████▌  |  314MB /  416MB, 87.1MB/s
# New Data Upload               :  78%|███████▊  |  314MB /  402MB, 87.1MB/s
#
# Processing Files (0 / 1)      :  81%|████████  |  335MB /  416MB, 88.1MB/s
# New Data Upload               :  83%|████████▎ |  335MB /  402MB, 88.1MB/s
#
# Processing Files (0 / 1)      :  85%|████████▍ |  352MB /  416MB, 87.9MB/s
# New Data Upload               :  85%|████████▍ |  352MB /  416MB, 87.9MB/s
#
# Processing Files (0 / 1)      :  93%|█████████▎|  388MB /  416MB, 92.4MB/s
# New Data Upload               :  93%|█████████▎|  388MB /  416MB, 92.4MB/s
#
# Processing Files (0 / 1)      : 100%|█████████▉|  415MB /  416MB, 94.4MB/s
# New Data Upload               : 100%|█████████▉|  415MB /  416MB, 94.4MB/s
#
#                               : 100%|█████████▉|  415MB /  416MB
#
#                               : 100%|█████████▉|  415MB /  416MB
#
#                               : 100%|█████████▉|  415MB /  416MB
#
# Processing Files (1 / 1)      : 100%|██████████|  416MB /  416MB, 79.9MB/s
# New Data Upload               : 100%|██████████|  416MB /  416MB, 79.9MB/s
#
#                               : 100%|██████████|  416MB /  416MB
#
#                               : 100%|██████████|  416MB /  416MB
#
# Processing Files (1 / 1)      : 100%|██████████|  416MB /  416MB, 74.2MB/s
# New Data Upload               : 100%|██████████|  416MB /  416MB, 74.2MB/s
#                               : 100%|██████████|  416MB /  416MB
# Uploading the dataset shards: 100%|██████████| 6/6 [01:32<00:00, 15.38s/it]
# Generating train split: 100%|██████████| 18010/18010 [00:07<00:00, 2507.06 examples/s]
# [verify] RohanRamesh/hi-en-synth-cs:synth_t2 OK - 18,010 rows, 23.95 h, 16000 Hz
# done -> RohanRamesh/hi-en-synth-cs
# next: 02_train.ipynb
